# %% [markdown]
# ### Problem Statement

# %% [markdown]
# What can I do to boost rentals as an AirBNB owner in Boston?

# %% [markdown]
# ### Hypothesis/Assumptions

# %% [markdown]
# Hypothesis - Certain phrases and amenities in the description, as well a good price point along with availability
# contribute to an AirBNB being rented Frequently
#
# Assumptions - Both review volume and rating are good indicators of how well and AirBNB is doing.

# %% [markdown]
# ### Goals and Success metrics

# %% [markdown]
# Goals - To identify several qualitative and quantitative factors that contribute to a high number of positive reviews and assist in the marketability of AirBNB
#
# Success Metrics - A larger number of good reviews, and reviews per month to quantify rental frequency.

# %% [markdown]
# ### Risks or limitations

# %% [markdown]
# There is not a specific value for profitability or total rentals so I will be needing to make assumptions based
# reviews/quality of reviews/number of reviews etc.

# %% [markdown]
# ### Data

# %%
import pandas as pd
pd.set_option('display.max_columns', 999)
AB_Data = pd.read_csv('./listings.csv')
AB_Data.head(5)
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# ...
